# %% [markdown]
# UNSUPERVISED LEARNING

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

data = {
    'Customer': ['Alice', 'Bob', 'Charlie', 'David','Manthan','Riya'],
    'Age' : [25,30,40,35,28,32],
    'Spending' : [200,300,400,560,80,150]
}

df = pd.DataFrame(data)

X=df[['Age','Spending']]

model = KMeans(n_clusters=2, random_state=42,n_init=10)

df['Group'] = model.fit_predict(X)

plt.figure(figsize=(8,6))

for group in df['Group'].unique():
    group_data = df[df['Group']== group]#{0,1}
    plt.scatter(group_data['Age'],group_data['Spending'],label=f'Group {group}')

plt.xlabel('Age')
plt.ylabel('Spending')
plt.title('Customer Segmentation')
plt.legend()
plt.grid(True)
plt.show()
print(df)
# Out:
#   Customer  Age  Spending  Group
# 0    Alice   25       200      1
# 1      Bob   30       300      1
# 2  Charlie   40       400      0
# 3    David   35       560      0
# 4  Manthan   28        80      1
# 5     Riya   32       150      1

# %% [markdown]
# PCA(priciple componenet analysis)  dimention reduction technique

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

data = {
    'Age': [25,30,33,40,45,60],
    'Income':[50000,60000,55000,100000,200000,150000],
    'Spending': [70,60,65,50,40,30],
    "Savings": [20000,30000,25000,50000,5000,70000]


}

df = pd.DataFrame(data)

scaler=StandardScaler()
SCaled_data = scaler.fit_transform(df)

pca = PCA(n_components=2)
pca_result = pca.fit_transform(SCaled_data)

pca_df = pd.DataFrame(data=pca_result, columns=['PCA1','PCA2'])

explained_variance = pca.explained_variance_ratio_
print("variance captured by each component")
print(np.round(explained_variance * 100,2))

plt.figure(figsize=(8,6))
plt.scatter(pca_df['PCA1'],pca_df['PCA2'])
plt.xlabel('pca1')
plt.ylabel('pca2')
plt.title('PCA of Customer Data')
plt.grid(True)
plt.show()
print(pca_df)
# Out:
# variance captured by each component
# [74.38 24.73]
#        PCA1      PCA2
# 0  2.068331  0.004654
# 1  1.168940  0.272914
# 2  1.344306  0.174245
# 3 -0.394702  0.671922
# 4 -1.233320 -2.102441
# 5 -2.953554  0.978705
